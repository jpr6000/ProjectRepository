# %% [markdown]
# # Lab 2 - Jarred Rolle

# %% [markdown]
# First, I linked enclosures to pets, as a single enclousre is used to to house a single pet, and the pet ID can be used to find what enclosure the pet is kept in. The pet table is linked to the pet food table as a single pet can eat more than one portion of food in a given day and a pet is given a specific type and amount of food. Customers is linked to both the pet food purchases table and pet purchases table as the receipt for each of these will link the customer to the purchase. I then linked the pets table to the pets receipt table and the pet food table to the pet food purchases table using the receipt primary key so that what was purchased it and what customer purchased it are linked by the receipt.

# %% [markdown]
# ![Lab2PetShopDiagram.png](data:image/png;base64,...)
